# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyaz127/TNS-Practice/blob/main/Batch2_day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mini Project Question:
# you are a data analyst for this supermarket analyze the dataset using at least 7 different matplotlib plots.
# For each plot answer:
# 1.Why do you choose this graph?
# 2.What business question does it answer?
# 3.What insight did you obtain?

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-075b5f4a-1143-41b1-bb53-e25054420467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-075b5f4a-1143-41b1-bb53-e25054420467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("supermarket_dataset.csv")
df.head()
# Out:
#    Order_ID Customer_Name Product Category  Quantity  Price       City  \
# 0      1001  Rahul Sharma    Milk    Dairy       2.0   50.0  Hyderabad
# 1      1002   Priya Verma   Bread   Bakery       1.0   40.0      Delhi
# 2      1003    Amit Kumar    Rice  Grocery       5.0   60.0     Mumbai
# 3      1004    Neha Singh    Eggs    Dairy      12.0    6.0  Bangalore
# 4      1005  Rahul Sharma    Milk    Dairy       2.0   50.0  Hyderabad
#
#   Payment_Method  Order_Date
# 0           Cash  2025-01-05
# 1            UPI  2025-01-06
# 2           Card  2025-01-07
# 3           Cash  2025-01-08
# 4           Cash  2025-01-05

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Customer_Name     1
# Product           0
# Category          0
# Quantity          1
# Price             1
# City              1
# Payment_Method    0
# Order_Date        0
# dtype: int64

# %%
df["City"].fillna(df["City"].mode()[0],inplace=True)
df["Price"].fillna(df["Price"].mean(),inplace=True)
df['Quantity'].fillna(df['Quantity'].mean(),inplace=True)
df["Customer_Name"].fillna(df["Customer_Name"].mode()[0],inplace=True )
# Out:
# /tmp/ipykernel_575/2715181247.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna(df["City"].mode()[0],inplace=True)
# /tmp/ipykernel_575/2715181247.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Customer_Name     0
# Product           0
# Category          0
# Quantity          0
# Price             0
# City              0
# Payment_Method    0
# Order_Date        0
# dtype: int64

# %%
print(df)
# Out:
#     Order_ID Customer_Name   Product       Category   Quantity       Price  \
# 0       1001  Rahul Sharma      Milk          Dairy   2.000000   50.000000
# 1       1002   Priya Verma     Bread         Bakery   1.000000   40.000000
# 2       1003    Amit Kumar      Rice        Grocery   5.000000   60.000000
# 3       1004    Neha Singh      Eggs          Dairy  12.000000    6.000000
# 4       1005  Rahul Sharma      Milk          Dairy   2.000000   50.000000
# 5       1006  Anjali Gupta     Sugar        Grocery   3.000000   45.000000
# 6       1007    Vikram Rao      Soap  Personal Care   4.000000   30.000000
# 7       1008   Sneha Patel   Shampoo  Personal Care   1.000000  180.000000
# 8       1009     Rohan Das    Butter          Dairy   2.000000   70.000000
# 9       1010   Kiran Reddy     Juice      Beverages   3.000000   90.000000
# 10      1011   Priya Verma       Tea        Grocery   2.000000  120.000000
# ...

# %%
# Line Plot
plt.plot(df.groupby('Payment_Method')['Price'].sum())
plt.xlabel("Payment Mode")
plt.ylabel("Price")
plt.title("Payment Mode Vs Price")
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: which payment mode has beeing generating more revenue.
# 2. What business question does it answer?
# Ans:Customers are interested in which payment mode.
# 3. What insight did you obtain?
# Ans: Most of the customers are willing to pay through UPI so Try to upgrade UPI methods and Eliminate card Methods.

# %%
#Bar plot
plt.figure(figsize=(10,5))
plt.bar(df['Product'],df['Quantity'])
plt.xlabel("Products")
plt.ylabel("Quantity")
plt.title("Orders by Category")
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: To compare the number of orders by different category.
# 2. What business question does it answer?
# Ans:Which product has more demand in the market.and less demand.
# 3. What insight did you obtain?
# Ans: Maintainance of the demanded product.

# %%
#Scatter Plot
plt.scatter(df['Quantity'],df['Price'])
plt.xlabel("Quantity")
plt.ylabel("Price")
plt.title("Price Vs Quantity")
plt.grid()
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: To Know the relation between two numerical variables.
# 2. What business question does it answer?
# Ans:does the price affect the quantity order by customer.
# 3. What insight did you obtain?
# Ans: Quantity and price are inversely proportional
# .

# %%
#Histogram Plot
plt.hist(df['Price'])
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: To Know the frequency of the Price by customers.
# 2. What business question does it answer?
# Ans: What price range has more customers buy.
# 3. What insight did you obtain?
# Ans: low to middle range priced have more in damand.

# %%
#Box Plot
plt.boxplot(df['Price'])
plt.grid()
plt.ylabel("Price")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: finding the Outliers.
# 2. What business question does it answer?
# Ans: What typical price range of the products?
# 3. What insight did you obtain?
# Ans: we can able to identify lowest=10 and highest price=125 and median price=50,and there are two outliers (180,250)

# %%
#Pie Chart
plt.figure(figsize=(15,10))
df.groupby('Product')['Quantity'].sum().plot(kind='pie',autopct='%1.1f%%')
plt.title("Quantity by Product")
plt.show()

# %% [markdown]
# 1. Why did you choose this graph?
# Ans: To Know the part of the whole quantity.
# 2. What business question does it answer?
# Ans: which products are sold highest quantity?
# 3. What insight did you obtain?
# Ans: its clear to the distribution of the products.eggs(40.2%).

# %%
#Heatmap
plt.figure(figsize=(10,5))
corr=df[["Quantity","Price"]].corr()
plt.imshow(corr,cmap='hot',interpolation='nearest')
plt.title("Correlation Matrix")
plt.colorbar()
plt.xticks(range(len(corr)),corr.columns)
plt.yticks(range(len(corr)),corr.columns )
plt.show()
