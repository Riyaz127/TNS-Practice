# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyaz127/TNS-Practice/blob/main/Batch2_day05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Student report card program using.
lis=[]
Set={}
name=input("Enter Student Name: ")
age=int(input("Enter Your Age: "))

tup=(name,age)
dictionary={
}
lis.append(name)
total=0
no_of_subject=int(input("Enter no of subjects:"))
while no_of_subject>len(dictionary):
  subject=input("Enter the Subject:")
  sub=(subject)
  marks=int(input("Enter the marks:"))
  total +=marks
  dictionary[subject]=marks
print("-----------Report Card----------")
print(tup)
print(dictionary)
print("Total Marks: ",total)
# Out:
# Enter Student Name: Riyaz
# Enter Your Age: 24
# Enter no of subjects:2
# Enter the Subject:english
# Enter the marks:56
# Enter the Subject:Hindi
# Enter the marks:67
# -----------Report Card----------
# ('Riyaz', 24)
# {'english': 56, 'Hindi': 67}
# Total Marks:  123
