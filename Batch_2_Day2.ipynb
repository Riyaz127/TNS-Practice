# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyaz127/TNS-Practice/blob/main/Batch_2_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Introduction to Python

# %% [markdown]
# 1.print 'Hello World'

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2.store your name in variable and print

# %%
name="Riyaz"
print(name)
# Out:
# Riyaz

# %% [markdown]
# 3.store and print your age.

# %%
age=23
print(age)
# Out:
# 23

# %% [markdown]
# 4.adding of two variables.

# %%
x=5
y=10
sum=x+y
print(sum)
# Out:
# 15

# %% [markdown]
# 5.substraction of two numbers.

# %%
x=25
y=7
sub=x-y
print(sub)
# Out:
# 18

# %% [markdown]
# 6.multiply the two numbers.

# %%
x=6
y=7
mul=x*y
print(mul)
# Out:
# 42

# %% [markdown]
# 7.divide the two numbers.

# %%
x=25
y=5
div=x/y
print(div)
# Out:
# 5.0

# %% [markdown]
# 8.square of a number.

# %%
x=6
print(x**2)
# Out:
# 36

# %% [markdown]
# 9.cube of a number.

# %%
x=3
print(x**3)
# Out:
# 27

# %% [markdown]
# 10.swap of the variable values.

# %%
# SWAP using the Temp Variable

a=10
b=25
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 25
# 10

# %%
# SWAP using without Temp Variable.
m=27
r=46
m,r=r,m
print(m)
print(r)
# Out:
# 46
# 27
